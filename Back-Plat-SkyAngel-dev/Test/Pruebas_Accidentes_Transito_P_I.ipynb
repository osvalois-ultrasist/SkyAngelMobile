# %% [markdown]
# # Pruebas para: Accidentes de Transito (Puntos de interes)

# %%
import requests

# Construimos la URL de la API
Host = '127.0.0.1'
# Port = '8000'
Port = '5000'
Url = 'http://'+Host+':'+Port
Url
# Out:
# 'http://127.0.0.1:5000'

# %%
# Ejemplo de peticion CORRECTA                                      Tipo GET

# Enviar la solicitud GET
response = requests.get(Url+'/punto_interes/accidentes_transito')

# Imprimir la respuesta
print(response.status_code)
# print(response.json())
# Out:
# 200

# %%
print(response.text)
# Out:
# {
#   "type": "FeatureCollection",
#   "features": [
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -102.145803,
#           21.811436
#         ]
#       },
#       "properties": {
#         "Entidad": "Aguascalientes",
#         "Tipo": "Siniestros",
#         "Periodo de años ": "2018-2020",
#         "Total ": 669,
#         "Libre ": 666,
#         "Cuota ": 3,
#         "Periodo de años  ": "2021-2023",
#         "Total  ": 1086,
#         "Libre  ": 1084,
#         "Cuota  ": 2
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -102.37080300000001,
#           21.941339810567666
#         ]
#       },
#       "properties": {
#         "Entidad": "Aguascalientes",
#         "Tipo": "Lesionados",
#         "Periodo de años ": "2018-2020",
#         "Total ": 600,
#         "Libre ": 599,
#         "Cuota ": 1,
# ...
