# %% [markdown]
# # Este NB contiene pruebas para la coleccion de Mallados

# %%
import requests

# Construimos la URL de la API
Host = '127.0.0.1'
Port = '5000'
Url = 'http://'+Host+':'+Port
Url
# Out:
# 'http://127.0.0.1:5000'

# %% [markdown]
# ### ENDPOINT GEOCOMPORTAMIENTO (MALLADO)
#
# Devuelve un mallado de hexagonos conforme a la prediccion para:
# *   delito
# *   fuente
# *   temporalidad

# %%
# Ejemplo de peticion CORRECTA                                      Tipo POST

# Definir los datos en formato JSON
data = {
    'fuente': 'secretariado',
    'ID_delito': 1,
    'size_mallado': 500,
    'temporalidad': 'LastYear'
}

# Enviar la solicitud POST con el JSON
response = requests.post(Url+'/mallados/geocomportamiento', json=data)

# Imprimir la respuesta
print(response.status_code)
#print(response.json())
# Out:
# 200

# %%
# Este codigo guarda el geodataframe para ser consumido por otra aplicacion
#import geopandas as gpd 

#gdf = gpd.GeoDataFrame.from_features(response.json()['GeoJson'])
#gdf = gdf.rename(columns={'Color':'color'})
#gdf   
#ruta_salida = 'C:\\Users\\user\\Desktop\\sky-angel-app\\public\\New_Hegaonos_Div50_Terr.geojson'
#gdf.to_file(ruta_salida, driver='GeoJSON')

# %%
# Ejemplo de peticion CORRECTA                                      Tipo POST

# Definir los datos en formato JSON
data = {
    'fuente': 'reacciones_sky',
    'ID_delito': 1,
    'size_mallado': 50,
    'temporalidad': 'LastYear'
}

# Enviar la solicitud POST con el JSON
response = requests.post(Url+'/mallados/geocomportamiento', json=data)

# Imprimir la respuesta
print(response.status_code)
print(response.json())
# Out:
# 200
# {'GeoJson': {'features': [{'geometry': {'coordinates': [[[-97.121711, 15.2], [-97.342105, 15.581735], [-97.121711, 15.96347], [-96.680921, 15.96347], [-96.460526, 15.581735], [-96.680921, 15.2], [-97.121711, 15.2]]], 'type': 'Polygon'}, 'id': '0', 'properties': {'Color': '#ffcccc', 'ID_poligono': 0, 'LastYear': 0.0}, 'type': 'Feature'}, {'geometry': {'coordinates': [[[-95.799342, 15.2], [-96.019737, 15.581735], [-95.799342, 15.96347], [-95.358553, 15.96347], [-95.138158, 15.581735], [-95.358553, 15.2], [-95.799342, 15.2]]], 'type': 'Polygon'}, 'id': '1', 'properties': {'Color': '#ffcccc', 'ID_poligono': 1, 'LastYear': 0.0}, 'type': 'Feature'}, {'geometry': {'coordinates': [[[-93.154605, 15.2], [-93.375, 15.581735], [-93.154605, 15.96347], [-92.713816, 15.96347], [-92.493421, 15.581735], [-92.713816, 15.2], [-93.154605, 15.2]]], 'type': 'Polygon'}, 'id': '2', 'properties': {'Color': '#ffcccc', 'ID_poligono': 2, 'LastYear': 0.0}, 'type': 'Feature'}, {'geometry': {'coordin
], [-99.766447, 15.96347]]], 'type': 'Polygon'}, 'id': '10', 'properties': {'Color': '#ffcccc', 'ID_poligono': 10, 'LastYear': 0.0}, 'type': 'Feature'}, {'geometry': {'coordinates': [[[-98.444079, 15.96347], [-98.664474, 16.345205], [-98.444079, 16.72694], [-98.003289, 16.72694], [-97.782895, 16.345205], [-98.003289, 15.96347], [-98.444079, 15.96347]]], 'type': 'Polygon'}, 'id': '11', 'properties': {'Color': '#ffcccc', 'ID_poligono': 11, 'LastYear': 0.0}, 'type': 'Feature'}, {'geometry': {'coordinates': [[[-97.121711, 15.96347], [-97.342105, 16.345205], [-97.121711, 16.72694], [-96. ...

# %%
# Ejemplo de peticion INCORRECTA                                      Tipo POST

# Definir los datos en formato JSON
data = {
    'fuente': 'reacciones_sky',
    'ID_delito': 1,
    'size_mallado': 50,
    'temporalidad$$$$$$$$$$$$$$$$': 'LastYear'
}

# Enviar la solicitud POST con el JSON
response = requests.post(Url+'/mallados/geocomportamiento', json=data)

# Imprimir la respuesta
print(response.status_code)
print(response.json())
# Out:
# 400
# {'respuesta': 'Argumentos incorrectos'}

# %%
# Ejemplo de peticion INCORRECTA                                      Tipo POST

# Definir los datos en formato JSON
data = {
    'fuente': 'reacciones_sky',
    'ID_delito': 23456,   # No existe este delito
    'size_mallado': 50,
    'temporalidad': 'LastYear'
}

# Enviar la solicitud POST con el JSON
response = requests.post(Url+'/mallados/geocomportamiento', json=data)

# Imprimir la respuesta
print(response.status_code)
print(response.json())
# Out:
# 500
# {'respuesta': 'Fallo en el procesamiento de la informacion'}

# %% [markdown]
# ### ENDPINT GEOCOMPORTAMIENTO REDUCIDO (MALLADO)
#
# Devuelve un mallado de hexagonos conforme a la prediccion para:
# *   delito
# *   fuente
# *   temporalidad

# %%
# Ejemplo de peticion CORRECTA                                      Tipo POST

# Definir los datos en formato JSON
data = {
    'fuente': 'secretariado',
    'ID_delito': 1,
    'size_mallado': 500,
    'temporalidad': 'LastYear'
}

# Enviar la solicitud POST con el JSON
response = requests.post(Url+'/mallados/geocomportamiento-red', json=data)

# Imprimir la respuesta
print(response.status_code)
#print(response.json())
# Out:
# 200

# %%
# Este codigo guarda el geodataframe para ser consumido por otra aplicacion
#import geopandas as gpd 

#gdf = gpd.GeoDataFrame.from_features(response.json()['GeoJson'])
#gdf = gdf.rename(columns={'Color':'color'})
#   
#ruta_salida = 'C:\\Users\\user\\Desktop\\sky-angel-app\\public\\NewRed_Hegaonos_Div500_Terr.geojson'
#gdf.to_file(ruta_salida, driver='GeoJSON')
# Out:
# c:\Users\user\Desktop\Back_Plata\VE-Back\Lib\site-packages\pyogrio\raw.py:698: UserWarning: 'crs' was not provided.  The output dataset will not have projection information defined and may not be usable in other systems.
#   warnings.warn(

# %%
# Ejemplo de peticion CORRECTA                                      Tipo POST

# Definir los datos en formato JSON
data = {
    'fuente': 'reacciones_sky',
    'ID_delito': 1,
    'size_mallado': 500,
    'temporalidad': 'LastYear'
}

# Enviar la solicitud POST con el JSON
response = requests.post(Url+'/mallados/geocomportamiento', json=data)

# Imprimir la respuesta
print(response.status_code)
#print(response.json())
# Out:
# 200

# %%
# Ejemplo de peticion INCORRECTA                                      Tipo POST

# Definir los datos en formato JSON
data = {
    'fuente': 'reacciones_sky',
    'ID_delito': 1,
    'size_mallado': 50,
    'temporalidad$$$$$$$$$$$$$$$$': 'LastYear'
}

# Enviar la solicitud POST con el JSON
response = requests.post(Url+'/mallados/geocomportamiento-red', json=data)

# Imprimir la respuesta
print(response.status_code)
print(response.json())
# Out:
# 400
# {'respuesta': 'Argumentos incorrectos'}

# %% [markdown]
# ### ENDPOINT GEORUTA (GEOPUNTOS)
#
# Devuelve un mallado de hexagonos conforme a la prediccion para:
# *   delito
# *   fuente
# *   temporalidad

# %%
import json

# Abrimos el geojson con la informacion de la ruta
Ruta = 'C:\\Users\\user\\Desktop\\Sky-Angel-Steps\\Geo_Info3\\Datos\\Ruta_test.json'
with open(Ruta, 'r') as file:   Ruta = json.load(file)

# %%
# Ejemplo de peticion CORRECTA                                      Tipo POST

# Definir los datos en formato JSON
data = {
    'fuente': 'secretariado',
    'ID_delito': 1,
    'temporalidad': 'LastYear',
    'geopuntos': Ruta
}

# Enviar la solicitud POST con el JSON
response = requests.post(Url+'/mallados/georutavalues', json=data)

# Imprimir la respuesta
print(response.status_code)
print(response.json().keys())
print(response.json()['GeoCalculo'].keys())
# Out:
# 200
# dict_keys(['GeoCalculo'])
# dict_keys(['GeoJson', 'Globales'])

# %%
response.json()['GeoCalculo']['Globales']
# Out:
# {'Sum_DelPol': 1859.8999999999999}

# %%
# Ejemplo de peticion INCORRECTA                                      Tipo POST

# Definir los datos en formato JSON
data = {
    'fuente': 'secretariado',
    'ID_delito': 1,
    'temporalidad': 'LastYear',
    'geopuntoasds': Ruta
}

# Enviar la solicitud POST con el JSON
response = requests.post(Url+'/mallados/georutavalues', json=data)

# Imprimir la respuesta
print(response.status_code)
print(response.json().keys())
# Out:
# 400
# dict_keys(['respuesta'])

# %%
# Ejemplo de peticion INCORRECTA                                      Tipo POST

# Definir los datos en formato JSON
data = {
    'fuente': 'falla', # No exite esta fuente de datos
    'ID_delito': 1,
    'temporalidad': 'LastYear',
    'geopuntos': Ruta
}

# Enviar la solicitud POST con el JSON
response = requests.post(Url+'/mallados/georutavalues', json=data)

# Imprimir la respuesta
print(response.status_code)
print(response.json().keys())
# Out:
# 500
# dict_keys(['respuesta'])
